# %% [markdown]
# # Table S01. Strains selected for the GWAS panel

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Attaching package: 'data.table'
#
# The following objects are masked from 'package:lubridate':
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# The following objects are masked from 'package:dplyr':
#
#     between, first, last
#
# The following object is masked from 'package:purrr':
#
#     transpose

# %%
# source the helper functions
source(file.path("bin", "general.R"))
# Out:
# Attaching package: 'rebus'
# The following object is masked from 'package:stringr':
#
#     regex
# The following object is masked from 'package:ggplot2':
#
#     alpha
# Attaching package: 'gtools'
# The following object is masked from 'package:rebus':
#
#     capture
# Attaching package: 'kableExtra'
# The following object is masked from 'package:dplyr':
#
#     group_rows
# Attaching package: 'flextable'
# The following objects are masked from 'package:kableExtra':
#
#     as_image, footnote
# The following object is masked from 'package:purrr':
#
#     compose
# here() starts at /Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript
# $strain_table
# $strain_table$html
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S1/table_S1.html"
#
# $strain_table$tsv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S1/table_S1.tsv.zip"
#
# $strain_table$docx
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S1/table_S1.docx"
#
# ...

# %%
# get the list of strains in the GWAS
load(file.path("data", "processed", "phenotypes", "pheno.df.rda"))

# Read the strain means data
strains <- unique(pheno.df$strain)

# downlaod latest data from CeaNDR
ce_iso_loc <- data.table::fread("https://caendr.org/request-strains/download/c-elegans/20220216/strain-data/csv")

# Three strains have non-CaeNDR strain names in data,  c("CB4855" "CB4857" "PB306")
# these are c("ECA248" = "CB4855, ECA250 = "CB4857", "ECA259" = "PB306")
strains[!strains %in% ce_iso_loc$strain]
# Out:
# [1] "CB4855" "CB4857" "PB306"

# %% [markdown]
# ``` r
#
# tableS1
# ```
#
#            strain                                 previous_names caendr_release
#            <char>                                         <char>          <int>
#       1:      AB1                                                      20160408
#       2: BRC20263                                                      20170531
#       3:   CB4854                                            GA9       20160408
#       4:   CB4856 CB4856_(CGC_#3)|CB4856_CGC_3|CB4856_CGC|CB4856       20160408
#       5:  CX11264                                        HEY-034       20160408
#      ---
#     191:   WN2086                                        MGS1-15       20210121
#     192:   XZ1516                                                      20170531
#     193:   XZ1672                                                      20180413
#     194:   XZ1735                                                      20180413
#     195:   XZ2018                                                      20180413
#          source_lab  latitude   longitude               landscape
#              <char>     <num>       <num>                  <char>
#       1:        CGC -34.93000  138.590000
#       2:        BRC -33.86749  151.206989
#       3:        CGC  34.18900 -118.131000            Urban_garden
#       4:        CGC  21.33000 -157.860000            Rural_garden
#       5:         CX  34.13014 -118.114835 Botanical_garden_or_zoo
#      ---
#     191:         WN  51.97520    5.718727               Grassland
#     192:         XZ  22.14900 -159.668000
#     193:         XZ  47.68774 -122.300513            Urban_garden
#     194:         XZ -22.90000  -46.700000            Urban_garden
#     195:         XZ        NA          NA            Urban_garden
#          locality_description                  substrate
#                        <char>                     <char>
#       1:      South Australia                       Soil
#       2:      New South Wales
#       3:           California         Vegetal_litter/mix
#       4:               Hawaii Rotting_nut/pod/seed/fruit
#       5:           California                       Soil
#      ---
#     191:              Beekdal               Rotting_stem
#     192:               Hawaii Rotting_nut/pod/seed/fruit
#     193:           Washington Rotting_nut/pod/seed/fruit
#     194:   State of Sao Paulo Rotting_nut/pod/seed/fruit
#     195:
#                            substrate_comments substrate_temp ambient_temp
#                                        <char>          <num>        <num>
#       1:        soil under rotting vegetation             NA           NA
#       2:                                                  NA           NA
#       3:                     vegetable garden             NA           NA
#       4:                      pineapple field             NA           NA
#       5:                                 soil             NA           NA
#      ---
#     191: butterbur (Petasites hybridus); stem             NA           NA
#     192:                 rotten small berries             NA           NA
#     193:                             tomatoes             NA           NA
#     194:                   unidentified fruit             NA           NA
#     195:                                                  NA           NA
#          ambient_humidity associated_organism         sampled_by
#                     <num>              <char>             <char>
#       1:               NA                     D. Riddle, A. Bird
#       2:               NA                       C. Lee, N. Chang
#       3:               NA                             C. Johnson
#       4:               NA                              L. Hollen
#       5:               NA                          A. Sivasundar
#      ---
#     191:               NA                             M. Sterken
#     192:               NA                              M. Ailion
#     193:               NA                             B. Coleman
#     194:               NA                              M. Ailion
#     195:               NA                              M. Ailion
#                        isolated_by sampling_date
#                             <char>        <IDat>
#       1:        D. Riddle, A. Bird    1983-01-01
#       2:                 J.-C. Hsu    2014-08-04
#       3:                C. Johnson    1973-12-01
#       4:                 L. Hollen    1972-08-01
#       5:             A. Sivasundar    2003-09-01
#      ---
#     191: M. Sterken, L. van Sluijs    2019-10-07
#     192:                 M. Ailion    2014-10-15
#     193:                 M. Ailion    2015-08-01
#     194:                 M. Ailion    2015-11-07
#     195:                 M. Ailion    2016-10-01
#                                                                                                                                                                                                     notes
#                                                                                                                                                                                                    <char>
#       1:                                                                                                                                                                                  Tc1 pattern VII
#       2:
#       3: CGC says Isolated in May 1974 from vegetable garden on Garfias St, Altadena, California USA, Noted as identical to CB3198 by Hodgkin and Doniach. Hodgkin and Doniach say isolated December 1973
#       4:                                                                                                                                         Isolated from an unknown Hawaiian island pineapple field
#       5:                                                                                                                              isolated in Huntington Gardens, exact location in garden is unknown
#      ---
#     191:                                                                                                                                                                        Sampling_2019_Results.pdf
#     192:
#     193:                                                                                              from rotten tomatoes from Picardo Farm P-patch community garden on 82nd and Ravenna Ave NE, Seattle
#     194:                                                                                                                                                 Another fruit from the same tree had C. briggsae
#     195:
