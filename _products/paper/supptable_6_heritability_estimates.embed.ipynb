# %% [markdown]
# # Table S06. Heritability estimates for toxicant conditions

# %%
library(dplyr)
# Out:
# Attaching package: 'dplyr'
# The following objects are masked from 'package:stats':
#
#     filter, lag
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
# Attaching package: 'data.table'
# The following objects are masked from 'package:dplyr':
#
#     between, first, last

# %%
#| include: false

# load the functions to save the output
source("bin/outs.R")
# Out:
# Attaching package: 'kableExtra'
# The following objects are masked from 'package:flextable':
#
#     as_image, footnote
# The following object is masked from 'package:dplyr':
#
#     group_rows
# here() starts at /Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript
# $strain_table
# $strain_table$html
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S1/table_S1.html"
#
# $strain_table$tsv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S1/table_S1.tsv.zip"
#
# $strain_table$docx
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S1/table_S1.docx"
#
# $strain_table$csv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S1/table_S1.csv"
#
#
# $tox_table_ft
# $tox_table_ft$html
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S2/table_S2.html"
#
# $tox_table_ft$tsv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S2/table_S2.tsv.zip"
#
# $tox_table_ft$docx
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S2/table_S2.docx"
#
# $tox_table_ft$csv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S2/table_S2.csv"
#
#
# $trait_table
# $trait_table$html
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S3/table_S3.html"
#
# $trait_table$tsv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S3/table_S3.tsv.zip"
#
# $trait_table$docx
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S3/table_S3.docx"
#
# $trait_table$csv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S3/table_S3.csv"
#
#
# $outlier_ft
# $outlier_ft$html
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S4/table_S4.html"
#
# $outlier_ft$tsv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S4/table_S4.tsv.zip"
#
# $outlier_ft$docx
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S4/table_S4.docx"
#
# $outlier_ft$csv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S4/table_S4.csv"
#
#
# $group_summary
# $group_summary$html
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S5/table_S5.html"
#
# $group_summary$tsv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S5/table_S5.tsv.zip"
#
# $group_summary$docx
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S5/table_S5.docx"
#
# $group_summary$csv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S5/table_S5.csv"
#
#
# $heritability_summary
# $heritability_summary$html
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S6/table_S6.html"
#
# $heritability_summary$tsv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S6/table_S6.tsv.zip"
#
# $heritability_summary$docx
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S6/table_S6.docx"
#
# $heritability_summary$csv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S6/table_S6.csv"
#
#
# $qtl_detected_table
# $qtl_detected_table$html
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S7/table_S7.html"
#
# $qtl_detected_table$tsv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S7/table_S7.tsv.zip"
#
# $qtl_detected_table$docx
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S7/table_S7.docx"
#
# $qtl_detected_table$csv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S7/table_S7.csv"
#
#
# $candidate_genes
# $candidate_genes$html
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S8/table_S8.html"
#
# $candidate_genes$tsv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S8/table_S8.tsv.zip"
#
# $candidate_genes$docx
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S8/table_S8.docx"
#
# $candidate_genes$csv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S8/table_S8.csv"
#
#
# $overlap_ft
# $overlap_ft$html
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S9/table_S9.html"
#
# $overlap_ft$tsv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S9/table_S9.tsv.zip"
#
# $overlap_ft$docx
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S9/table_S9.docx"
#
# $overlap_ft$csv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S9/table_S9.csv"
#
#
# $inbred_qtl_ranking_ft
# $inbred_qtl_ranking_ft$html
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S10/table_S10.html"
#
# $inbred_qtl_ranking_ft$tsv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S10/table_S10.tsv.zip"
#
# $inbred_qtl_ranking_ft$docx
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S10/table_S10.docx"
#
# $inbred_qtl_ranking_ft$csv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S10/table_S10.csv"
#
#
# $orthologs_ft
# $orthologs_ft$html
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S11/table_S11.html"
#
# $orthologs_ft$tsv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S11/table_S11.tsv.zip"
#
# $orthologs_ft$docx
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S11/table_S11.docx"
#
# $orthologs_ft$csv
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/tables/table_S11/table_S11.csv"
#
#
# $heritability_all_classes
# $heritability_all_classes$png
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_1/figure_1.png"
#
# $heritability_all_classes$eps
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_1/figure_1.eps"
#
# $heritability_all_classes$jpg
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_1/figure_1.jpg"
#
# $heritability_all_classes$tiff
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_1/figure_1.tiff"
#
#
# $phenotype_correlations
# $phenotype_correlations$png
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_2/figure_2.png"
#
# $phenotype_correlations$eps
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_2/figure_2.eps"
#
# $phenotype_correlations$jpg
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_2/figure_2.jpg"
#
# $phenotype_correlations$tiff
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_2/figure_2.tiff"
#
#
# $manhattan_plots
# $manhattan_plots$png
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_3/figure_3.png"
#
# $manhattan_plots$eps
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_3/figure_3.eps"
#
# $manhattan_plots$jpg
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_3/figure_3.jpg"
#
# $manhattan_plots$tiff
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_3/figure_3.tiff"
#
#
# $tox.effect.bubble
# $tox.effect.bubble$png
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_4/figure_4.png"
#
# $tox.effect.bubble$eps
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_4/figure_4.eps"
#
# $tox.effect.bubble$jpg
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_4/figure_4.jpg"
#
# $tox.effect.bubble$tiff
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_4/figure_4.tiff"
#
#
# $qtl_overlaps
# $qtl_overlaps$png
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_5/figure_5.png"
#
# $qtl_overlaps$eps
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_5/figure_5.eps"
#
# $qtl_overlaps$jpg
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_5/figure_5.jpg"
#
# $qtl_overlaps$tiff
# [1] "/Users/ryanmckeown/Desktop/ToxinGWAS_Manuscript/figures/figure_5/figure_5.tiff"

# %% [markdown]
# # Inputs

# %%
# load H2 and h2 rdata files
load("data/processed/heritability/h2.list.mean.rda")

# load the H2 data from boots
load("data/processed/heritability/H2.parametric.boot.list.10000.rda")

# load the tox data
tox <- data.table::fread("data/processed/tox_data/con_metadata.csv") %>%
  dplyr::filter(type == "Toxicant")

# %% [markdown]
# # Main

# %%
## H2 ##
# setup as data frame
H2.df.list <- NULL
for (i in 1:length(H2.list)) {
  drug <- names(H2.list)[i]
  o <- H2.list[[i]][[1]] %>%
    dplyr::mutate(drug = drug)

  H2.df.list[[i]] <- o
}
# bind list
H2.df <- data.table::rbindlist(H2.df.list) %>%
  dplyr::filter(drug %in% unique(tox$drug))

## h2 ##

h2.df.list.b <- NULL
for (i in 1:length(h2.list.mean)) {
  drug <- names(h2.list.mean)[i]
  o <- h2.list.mean[[i]] %>%
    dplyr::mutate(drug = drug)

  h2.df.list.b[[i]] <- o
}
# bind list
h2.df.b <- data.table::rbindlist(h2.df.list.b)

h.b2 <- dplyr::left_join(H2.df, h2.df.b) %>%
  dplyr::left_join(tox) %>%
  # dplyr::filter(big_class != "Flame Retardant") %>%
  dplyr::mutate(nice_drug_label2 = stringr::str_replace(nice_drug_label2, pattern = "uM", replacement = "µM"))
# Out:
# Joining with `by = join_by(drug)`
# Joining with `by = join_by(drug)`

# %%
# Clean up the summary data for the supplement
h2_summary_clean <- h.b2 %>%
  dplyr::select(
    nice_drug_label2,
    big_class,
    H2.point,
    H2.CI.lower,
    H2.CI.upper,
    H2.CI.level,
    h2.point,
    h2.lower,
    h2.upper
  ) %>%
  rename(
    "Toxicant" = nice_drug_label2,
    "Class" = big_class,
    "Broad-sense heritability" = H2.point,
    "Broad-sense heritability CI lower" = H2.CI.lower,
    "Broad-sense heritability CI upper" = H2.CI.upper,
    "Broad-sense heritability CI level" = H2.CI.level,
    "Narrow-sense heritability" = h2.point,
    "Narrow-sense heritability CI lower" = h2.lower,
    "Narrow-sense heritability CI upper" = h2.upper
  ) %>%
  dplyr::group_by(Class) %>%
  dplyr::arrange(Class, `Broad-sense heritability`)

# %%
# Calculate group means
group_means <- h2_summary_clean %>%
  dplyr::summarise(
    Toxicant = "Group Mean",
    `Broad-sense heritability` = mean(`Broad-sense heritability`),
    `Broad-sense heritability CI lower` = mean(`Broad-sense heritability CI lower`),
    `Broad-sense heritability CI upper` = mean(`Broad-sense heritability CI upper`),
    `Narrow-sense heritability` = mean(`Narrow-sense heritability`),
    `Narrow-sense heritability CI lower` = mean(`Narrow-sense heritability CI lower`),
    `Narrow-sense heritability CI upper` = mean(`Narrow-sense heritability CI upper`)
  )

# Combine individual and group mean data
h2_summary_with_means <- dplyr::bind_rows(
  h2_summary_clean,
  group_means
) %>%
  dplyr::arrange(Class, Toxicant == "Group Mean", `Broad-sense heritability`)

# Create grouped data by Class
grouped_data <- as_grouped_data(
  x = h2_summary_with_means,
  groups = "Class"
)

# %%
# Create flextable from grouped data
heritability_ft <- as_flextable(
  grouped_data,
  col_keys = c(
    "Toxicant",
    "Broad-sense heritability",
    "Narrow-sense heritability"
  ),
  hide_grouplabel = TRUE
) %>%
  flextable::set_header_labels(
    values = list(
      "Toxicant" = "Toxicant",
      "Broad-sense heritability" = "Broad-sense heritability (H²)",
      "Narrow-sense heritability" = "Narrow-sense heritability (h²)"
    )
  ) %>%
  # Combine heritability values with their CIs
  flextable::compose(
    j = "Broad-sense heritability",
    i = ~ !is.na(Toxicant),
    value = as_paragraph(
      sprintf("%.3f", `Broad-sense heritability`),
      " [",
      sprintf("%.3f", `Broad-sense heritability CI lower`),
      ", ",
      sprintf("%.3f", `Broad-sense heritability CI upper`),
      "]"
    )
  ) %>%
  flextable::compose(
    j = "Narrow-sense heritability",
    i = ~ !is.na(Toxicant),
    value = as_paragraph(
      sprintf("%.3f", `Narrow-sense heritability`),
      " [",
      sprintf("%.3f", `Narrow-sense heritability CI lower`),
      ", ",
      sprintf("%.3f", `Narrow-sense heritability CI upper`),
      "]"
    )
  ) %>%
  # make only the groups and header bold
  flextable::bold(
    j = 1,
    i = ~ is.na(Toxicant) | Toxicant == "Group Mean",
    bold = TRUE,
    part = "body"
  ) %>%
  flextable::bold(part = "header") %>%
  flextable::line_spacing(space = 1, part = "all") %>%
  flextable::align(j = 1, align = "left") %>%
  flextable::align(j = 2:3, align = "center") %>%
  flextable::hline(
    i = ~ is.na(Toxicant) | Toxicant == "Group Mean",
    part = "body"
  ) %>%
  flextable::set_table_properties(
    layout = "autofit",
    width = 1,
    opts_word = list(
      split = FALSE,
      keep_with_next = TRUE
    )
  )
# Save the table using standardized functions
save_supp_table_csv(h2_summary_with_means, "heritability_summary")
save_supp_table_flextable(heritability_ft, "heritability_summary")

# %%
heritability_ft
# Out:
# <div class="tabwid"><style>.cl-26f2ac20{table-layout:auto;width:100%;}.cl-26efae80{font-family:'Times New Roman';font-size:11pt;font-weight:bold;font-style:normal;text-decoration:none;color:rgba(0, 0, 0, 1.00);background-color:transparent;}.cl-26efae8a{font-family:'Times New Roman';font-size:11pt;font-weight:normal;font-style:normal;text-decoration:none;color:rgba(0, 0, 0, 1.00);background-color:transparent;}.cl-26f0e6e2{margin:0;text-align:center;border-bottom: 0 solid rgba(0, 0, 0, 1.00);border-top: 0 solid rgba(0, 0, 0, 1.00);border-left: 0 solid rgba(0, 0, 0, 1.00);border-right: 0 solid rgba(0, 0, 0, 1.00);padding-bottom:0.1pt;padding-top:0.1pt;padding-left:0.1pt;padding-right:0.1pt;line-height: 1;background-color:transparent;}.cl-26f0e6ec{margin:0;text-align:left;border-bottom: 0 solid rgba(0, 0, 0, 1.00);border-top: 0 solid rgba(0, 0, 0, 1.00);border-left: 0 solid rgba(0, 0, 0, 1.00);border-right: 0 solid rgba(0, 0, 0, 1.00);padding-bottom:0.1pt;padding-top:0.1pt;padding-left:0.1pt;padding-right:0.1pt;line-height: 1;background-color:transparent;}.cl-26f0eeb2{background-color:transparent;vertical-align: middle;border-bottom: 0.75pt solid rgba(0, 0, 0, 1.00);border-top: 0.75pt solid rgba(0, 0, 0, 1.00);border-left: 0 solid rgba(255, 255, 255, 0.00);border-right: 0 solid rgba(255, 255, 255, 0.00);margin-bottom:0;margin-top:0;margin-left:0;margin-right:0;}.cl-26f0eebc{background-color:transparent;vertical-align: middle;border-bottom: 1pt solid rgba(190, 190, 190, 1.00);border-top: 0 solid rgba(255, 255, 255, 0.00);border-left: 0 solid rgba(255, 255, 255, 0.00);border-right: 0 solid rgba(255, 255, 255, 0.00);margin-bottom:0;margin-top:0;margin-left:0;margin-right:0;}.cl-26f0eebd{background-color:transparent;vertical-align: middle;border-bottom: 1pt solid rgba(190, 190, 190, 1.00);border-top: 0 solid rgba(255, 255, 255, 0.00);border-left: 0 solid rgba(255, 255, 255, 0.00);border-right: 0 solid rgba(255, 255, 255, 0.00);margin-bottom:0;margin-top:0;margin-left:0;margin-right:0;}.cl-26f0eebe{background-color:transparent;vertical-align: middle;border-bottom: 0 solid rgba(255, 255, 255, 0.00);border-top: 1pt solid rgba(190, 190, 190, 1.00);border-left: 0 solid rgba(255, 255, 255, 0.00);border-right: 0 solid rgba(255, 255, 255, 0.00);margin-bottom:0;margin-top:0;margin-left:0;margin-right:0;}.cl-26f0eec6{background-color:transparent;vertical-align: middle;border-bottom: 0 solid rgba(255, 255, 255, 0.00);border-top: 1pt solid rgba(190, 190, 190, 1.00);border-left: 0 solid rgba(255, 255, 255, 0.00);border-right: 0 solid rgba(255, 255, 255, 0.00);margin-bottom:0;margin-top:0;margin-left:0;margin-right:0;}.cl-26f0eec7{background-color:transparent;vertical-align: middle;border-bottom: 0 solid rgba(255, 255, 255, 0.00);border-top: 0 solid rgba(255, 255, 255, 0.00);border-left: 0 solid rgba(255, 255, 255, 0.00);border-right: 0 solid rgba(255, 255, 255, 0.00);margin-bottom:0;margin-top:0;margin-left:0;margin-right:0;}.cl-26f0eed0{background-color:transparent;vertical-align: middle;border-bottom: 0 solid rgba(255, 255, 255, 0.00);border-top: 0 solid rgba(255, 255, 255, 0.00);border-left: 0 solid rgba(255, 255, 255, 0.00);border-right: 0 solid rgba(255, 255, 255, 0.00);margin-bottom:0;margin-top:0;margin-left:0;margin-right:0;}.cl-26f0eed1{background-color:transparent;vertical-align: middle;border-bottom: 1pt solid rgba(190, 190, 190, 1.00);border-top: 1pt solid rgba(190, 190, 190, 1.00);border-left: 0 solid rgba(255, 255, 255, 0.00);border-right: 0 solid rgba(255, 255, 255, 0.00);margin-bottom:0;margin-top:0;margin-left:0;margin-right:0;}.cl-26f0eeda{background-color:transparent;vertical-align: middle;border-bottom: 1pt solid rgba(190, 190, 190, 1.00);border-top: 1pt solid rgba(190, 190, 190, 1.00);border-left: 0 solid rgba(255, 255, 255, 0.00);border-right: 0 solid rgba(255, 255, 255, 0.00);margin-bottom:0;margin-top:0;margin-left:0;margin-right:0;}</style><table data-quarto-disable-processing='true' class='cl-26f2ac20'><thead><tr style="o ...
